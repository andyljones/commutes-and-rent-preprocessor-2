-- %%
local std = require('std')

local https = require('ssl.https')
local cjson = require('cjson')

local API_ID = '64dd8f8c'
local API_KEY = '8f945b259bf29848031c8dbdb7abf4b3'

function request_api(stem)
    local url = string.format('https://api.tfl.gov.uk/%s&app_id=%s&app_key=%s', stem, API_ID, API_KEY)
    local body, code, _, _ = https.request(url)
    
    assert(code == 200, string.format('Invalid response to url %s. Code: %d', url, code))
        
    return cjson.decode(body)
end

function get_line_data():
    return request_api('Line?')

function get_lines_of_interest(line_data)
    local results = {}
    for k, v in pairs(line_data) do
        if v.modeName == 'tube' or v.modeName == 'overground' then table.insert(results, v) end
    end
    
    return results
end

function format_stem(...)
    local query = (...).query
    
    local stem = query .. '?'
    for k, v in pairs(...) do
        if k ~= 'query' then
            stem = string.format('%s&%s=%s', stem, k, v)
        end
    end
    
    return stem
end

function get_stations_for_line(name)
    local stem = format_stem{
        query='Line/ids/StopPoints',
        ids=name
    }

    return request_api(stem)
end

function get_station_names(station_data)
    local ids = {}
    for _, v in pairs(station_data) do
        ids[v.id] = v.commonName
    end
    return ids
end

function get_timetables(line_name, station_name, direction)
    stem = format_stem{
        query='Line/id/Timetable/fromStopPointId', 
        fromStopPointId=station_name, 
        id=line_name,
        direction=direction}
    
    return request_api(stem)
end

function get_intervals(timetable, stations)
    local routes = timetable.timetable.routes
    local results = {}
    for route_num, route in pairs(routes) do
        results[route_num] = {}
        for interval_num, intervals in pairs(route.stationIntervals) do
            results[route_num][interval_num] = {}
            for _, interval in pairs(intervals.intervals) do
                station_name = stations[interval.stopId]
                results[route_num][interval_num][station_name] = interval.timeToArrival
            end
        end
    end
    return results
end
    

function get_intervals_for_line(line_name)
    local stations = get_station_names(get_stations_for_line(line_name))
    
    local results = {}
    for id, station_name in pairs(stations) do
        results[station_name] = {}
        for _, direction in pairs({'inbound', 'outbound'}) do
            local success, timetables = pcall(get_timetables, line_name, id, direction)

            if success then
                results[station_name][direction] = get_intervals(timetables, stations)
                print(string.format('Got results for %s in direction %s', station_name, direction))
            else
                print(string.format('Failed to get intervals for %s in direction %s', station_name, direction))
            end
        end
    end
    
    return results
end

function save_intervals_for_all_lines()
    local lines_ = get_lines_of_interest(request_api('Line?'))
end

-- %%
print(get_lines_of_interest(request_api('Line?')))
-- Out:
-- {
--   1 :
--     {
--       $type : Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities
--       name : Bakerloo
--       disruptedNaptanIds : table: 0x11f676c8
--       lineStatuses : table: 0x11f676f0
--       created : 2015-06-17T16:53:04.51
--       modified : 2015-06-17T16:53:04.51
--       id : bakerloo
--       routeSections :
--         {
--           1 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUEAC
--               originationName : Harrow & Wealdstone Underground Station
--               name : Harrow & Wealdstone Underground Station - Elephant & Castle Underground Station
--               destinationName : Elephant & Castle Underground Station
--               originator : 940GZZLUHAW
--               direction : inbound
--             }
--           2 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUHAW
--               originationName : Elephant & Castle Underground Station
--               name : Elephant & Castle Underground Station - Harrow & Wealdstone Underground Station
--               destinationName : Harrow & Wealdstone Underground Station
--               originator : 940GZZLUEAC
--               direction : outbound
--             }
--         }
--       modeName : tube
--     }
--   2 :
--     {
--       $type : Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities
--       name : Central
--       disruptedNaptanIds : table: 0x11a98098
--       lineStatuses : table: 0x11a980c0
--       created : 2015-06-17T16:53:04.323
--       modified : 2015-06-17T16:53:04.323
--       id : central
--       routeSections :
--         {
--           1 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUWRP
--               originationName : Hainault Underground Station
--               name : Hainault Underground Station - West Ruislip Underground Station
--               destinationName : West Ruislip Underground Station
--               originator : 940GZZLUHLT
--               direction : inbound
--             }
--           2 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUEBY
--               originationName : Hainault Underground Station
--               name : Hainault Underground Station - Ealing Broadway Underground Station
--               destinationName : Ealing Broadway Underground Station
--               originator : 940GZZLUHLT
--               direction : inbound
--             }
--           3 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUWRP
--               originationName : Epping Underground Station
--               name : Epping Underground Station - West Ruislip Underground Station
--               destinationName : West Ruislip Underground Station
--               originator : 940GZZLUEPG
--               direction : inbound
--             }
--           4 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUEBY
--               originationName : Epping Underground Station
--               name : Epping Underground Station - Ealing Broadway Underground Station
--               destinationName : Ealing Broadway Underground Station
--               originator : 940GZZLUEPG
--               direction : inbound
--             }
--           5 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUWRP
--               originationName : Hainault Underground Station
--               name : Hainault Underground Station - West Ruislip Underground Station
--               destinationName : West Ruislip Underground Station
--               originator : 940GZZLUHLT
--               direction : inbound
--             }
--           6 :
--             {
--               $type : Tfl.Api.Presentation.Entities.Mat
-- chedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUEBY
--               originationName : Hainault Underground Station
--               name : Hainault Underground Station - Ealing Broadway Underground Station
--               destinationName : Ealing Broadway Underground Station
--               originator : 940GZZLUHLT
--               direction : inbound
--             }
--           7 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUHLT
--               originationName : West Ruislip Underground Station
--               name : West Ruislip Underground Station - Hainault Underground Station
--               destinationName : Hainault Underground Station
--               originator : 940GZZLUWRP
--               direction : outbound
--             }
--           8 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUHLT
--               originationName : Ealing Broadway Underground Station
--               name : Ealing Broadway Underground Station - Hainault Underground Station
--               destinationName : Hainault Underground Station
--               originator : 940GZZLUEBY
--               direction : outbound
--             }
--           9 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUEPG
--               originationName : West Ruislip Underground Station
--               name : West Ruislip Underground Station - Epping Underground Station
--               destinationName : Epping Underground Station
--               originator : 940GZZLUWRP
--               direction : outbound
--             }
--           10 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUHLT
--               originationName : West Ruislip Underground Station
--               name : West Ruislip Underground Station - Hainault Underground Station
--               destinationName : Hainault Underground Station
--               originator : 940GZZLUWRP
--               direction : outbound
--             }
--           11 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUEPG
--               originationName : Ealing Broadway Underground Station
--               name : Ealing Broadway Underground Station - Epping Underground Station
--               destinationName : Epping Underground Station
--               originator : 940GZZLUEBY
--               direction : outbound
--             }
--         }
--       modeName : tube
--     }
--   3 :
--     {
--       $type : Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities
--       name : Circle
--       disruptedNaptanIds : table: 0x11a994a0
--       lineStatuses : table: 0x11a98c40
--       created : 2015-06-17T16:53:04.387
--       modified : 2015-06-17T16:53:04.387
--       id : circle
--       routeSections :
--         {
--           1 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUHSC
--               originationName : Edgware Road (Circle Line) Underground Station
--               name : Edgware Road (Circle Line) Underground Station - Hammersmith (H&C Line) Underground Station
--               destinationName : Hammersmith (H&C Line) Underground Station
--               originator : 940GZZLUERC
--               direction : inbound
--             }
--           2 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUERC
--               originationName : Hammersmith (H&C Line) Underground Station
--               name : Hammersmith (H&C Line) Underground Station - Edgware Road (Circle Line) Underground Station
--               destinationName : Edgware Road (Circle Line) Underground Station
--               originator : 940GZZLUHSC
--               direction : ou
-- tbound
--             }
--         }
--       modeName : tube
--     }
--   4 :
--     {
--       $type : Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities
--       name : District
--       disruptedNaptanIds : table: 0x11982080
--       lineStatuses : table: 0x119820a8
--       created : 2015-06-17T16:53:05.103
--       modified : 2015-06-17T16:53:05.103
--       id : district
--       routeSections :
--         {
--           1 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUWIM
--               originationName : Upminster Underground Station
--               name : Upminster Underground Station - Wimbledon Underground Station
--               destinationName : Wimbledon Underground Station
--               originator : 940GZZLUUPM
--               direction : inbound
--             }
--           2 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUWIM
--               originationName : Edgware Road (Circle Line) Underground Station
--               name : Edgware Road (Circle Line) Underground Station - Wimbledon Underground Station
--               destinationName : Wimbledon Underground Station
--               originator : 940GZZLUERC
--               direction : inbound
--             }
--           3 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUKOY
--               originationName : Edgware Road (Circle Line) Underground Station
--               name : Edgware Road (Circle Line) Underground Station - Kensington (Olympia) Underground Station
--               destinationName : Kensington (Olympia) Underground Station
--               originator : 940GZZLUERC
--               direction : inbound
--             }
--           4 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUEBY
--               originationName : Upminster Underground Station
--               name : Upminster Underground Station - Ealing Broadway Underground Station
--               destinationName : Ealing Broadway Underground Station
--               originator : 940GZZLUUPM
--               direction : inbound
--             }
--           5 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLURMD
--               originationName : Upminster Underground Station
--               name : Upminster Underground Station - Richmond Underground Station
--               destinationName : Richmond Underground Station
--               originator : 940GZZLUUPM
--               direction : inbound
--             }
--           6 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUEBY
--               originationName : Edgware Road (Circle Line) Underground Station
--               name : Edgware Road (Circle Line) Underground Station - Ealing Broadway Underground Station
--               destinationName : Ealing Broadway Underground Station
--               originator : 940GZZLUERC
--               direction : inbound
--             }
--           7 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLURMD
--               originationName : Edgware Road (Circle Line) Underground Station
--               name : Edgware Road (Circle Line) Underground Station - Richmond Underground Station
--               destinationName : Richmond Underground Station
--               originator : 940GZZLUERC
--               direction : inbound
--             }
--           8 :
--             {
--               $type : Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities
--               destination : 940GZZLUUPM
--               originationName : Wimbledon Underground Station
--               name : Wimbledon Underground Station - Upminster Underground Station
